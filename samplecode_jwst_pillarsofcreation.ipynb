# %%
pip install astropy

# %%
pip install astroquery

# %%
from astropy.io import fits

# %%
from astroquery.mast import Observations

# %%
obsByName = Observations.query_object("NGC 6611", radius="0.2 deg")
print("Number of results from all missions:", len(obsByName))
print(obsByName[:10])


# Filter for JWST observations
jwst_only = obsByName[obsByName['project'] == 'JWST']
print("\n\n JWST results only \n")
print(jwst_only)
# Out:
# Number of results from all missions: 59023
# intentType obs_collection provenance_name instrument_name ... srcDen   obsid        distance
# ---------- -------------- --------------- --------------- ... ------ --------- ------------------
#    science           TESS            SPOC      Photometer ...    nan 229777503                0.0
#    science           TESS            SPOC      Photometer ...    nan 229366205   47.7677421382677
#    science           TESS            SPOC      Photometer ...    nan 229366204  98.09053365037757
#    science           TESS            SPOC      Photometer ...    nan 229366206 125.58930906641713
#    science           TESS            SPOC      Photometer ...    nan 229422424 203.38344425886712
#    science           TESS            SPOC      Photometer ...    nan 229366207 203.38344425886712
#    science           TESS            SPOC      Photometer ...    nan 229366220 287.01086774890643
#    science           TESS            SPOC      Photometer ...    nan 229366218  663.8743003432548
#    science          SWIFT              --            UVOT ... 5885.0   1544858                0.0
#    science          SWIFT              --            UVOT ... 5885.0   1374120                0.0
#
#
#  JWST results only
#
#  intentType obs_collection provenance_name instrument_name ... srcDen   obsid        distance
# ----------- -------------- --------------- --------------- ... ------ --------- -----------------
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan 219392596 19.19685387609672
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan  89223710 19.32807064391856
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan  89223612 19.33069494680422
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan  89121540 23.65944965767131
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan  89121644 23.80278482317815
#     science           JWST         CALJWST    NIRCAM/IMAGE ...    nan 219392347 23.82016978702478
#     science           JWST         CALJWST      MIRI/IMAGE ...    nan  90712437 56.13747223777189
#     science           JWST         CALJWST      MIRI/IMAGE ...    nan  90746256 56.16411181430275
#     science           JWST         CALJWST      MIRI/IMAGE ...    nan  90712305 56.19533084036199
# calibration           JWST         CALJWST      MIRI/IMAGE ...    nan  90863116 338.3818871597592

# %%
print(jwst_only.keys(), '\n\n')
print(jwst_only['obsid', 'instrument_name', 'filters', 'obs_id','t_min'])
# Out:
# ['intentType', 'obs_collection', 'provenance_name', 'instrument_name', 'project', 'filters', 'wavelength_region', 'target_name', 'target_classification', 'obs_id', 's_ra', 's_dec', 'dataproduct_type', 'proposal_pi', 'calib_level', 't_min', 't_max', 't_exptime', 'em_min', 'em_max', 'obs_title', 't_obs_release', 'proposal_id', 'proposal_type', 'sequence_number', 's_region', 'jpegURL', 'dataURL', 'dataRights', 'mtFlag', 'srcDen', 'obsid', 'distance']
#
#
#   obsid   instrument_name   filters                  obs_id                      t_min
# --------- --------------- ----------- ------------------------------------ ------------------
# 219392596    NIRCAM/IMAGE       F200W jw02739-o001_t001_nircam_clear-f200w  59805.40325079491
#  89223710    NIRCAM/IMAGE       F090W jw02739-o001_t001_nircam_clear-f090w 59805.383864880554
#  89223612    NIRCAM/IMAGE       F187N jw02739-o001_t001_nircam_clear-f187n  59805.35664999352
#  89121540    NIRCAM/IMAGE F444W;F470N jw02739-o001_t001_nircam_f444w-f470n  59805.35664999352
#  89121644    NIRCAM/IMAGE       F444W jw02739-o001_t001_nircam_clear-f444w 59805.403251535645
# 219392347    NIRCAM/IMAGE       F335M jw02739-o001_t001_nircam_clear-f335m 59805.383864880554
#  90712437      MIRI/IMAGE      F1130W        jw02739-o002_t001_miri_f1130w    59821.607298025
#  90746256      MIRI/IMAGE      F1500W        jw02739-o002_t001_miri_f1500w 59821.622265616665
#  90712305      MIRI/IMAGE       F770W         jw02739-o002_t001_miri_f770w  59821.59162416991
#  90863116      MIRI/IMAGE      OPAQUE   jw01517005001_02201_00001_mirimage  59824.87666785232

# %%
obs_219392596 = jwst_only[(jwst_only['obsid']=='219392596')]
print("\nObservation 219392596 of NGC 6611: \n")
print(obs_219392596)

# get a list of Data Products available from the observations
dataProducts = Observations.get_product_list(obs_219392596)
print("\nData Products: \n")
print(dataProducts)
# Out:
# Observation 219392596 of NGC 6611:
#
# intentType obs_collection provenance_name instrument_name ... srcDen   obsid        distance
# ---------- -------------- --------------- --------------- ... ------ --------- -----------------
#    science           JWST         CALJWST    NIRCAM/IMAGE ...    nan 219392596 19.19685387609672
#
# Data Products:
#
#   obsID   obs_collection dataproduct_type ... dataRights calib_level filters
# --------- -------------- ---------------- ... ---------- ----------- -------
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           1   F200W
#  89101146           JWST            image ...     PUBLIC           2   F200W
#  89101146           JWST            image ...     PUBLIC           2   F200W
#       ...            ...              ... ...        ...         ...     ...
#  90863289           JWST            image ...     PUBLIC           2   F200W
#  90863289           JWST            image ...     PUBLIC           2   F200W
#  90863289           JWST            image ...     PUBLIC           2   F200W
#  90863289           JWST            image ...     PUBLIC           1   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# Length = 21806 rows

# %%
calibrated = dataProducts[(dataProducts['calib_level'] >= 3)]
print("Found ", len(calibrated), " data products with calibration level >= 3")
print(calibrated)
# See how we can differentiate the products
print("\n"
,calibrated.keys())
print(calibrated['obsID','productSubGroupDescription','description'])
# Out:
# Found  6  data products with calibration level >= 3
#   obsID   obs_collection dataproduct_type ... dataRights calib_level filters
# --------- -------------- ---------------- ... ---------- ----------- -------
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
# 219392596           JWST            image ...     PUBLIC           3   F200W
#
#  ['obsID', 'obs_collection', 'dataproduct_type', 'obs_id', 'description', 'type', 'dataURI', 'productType', 'productGroupDescription', 'productSubGroupDescription', 'productDocumentationURL', 'project', 'prvversion', 'proposal_id', 'productFilename', 'size', 'parent_obsid', 'dataRights', 'calib_level', 'filters']
#   obsID   productSubGroupDescription                 description
# --------- -------------------------- --------------------------------------------
# 219392596                       SEGM             target   (L3) : segmentation map
# 219392596                        ASN   source/target (L3) : association generator
# 219392596                       POOL        source/target (L3) : association pool
# 219392596                         --                                 Preview-Full
# 219392596                        CAT               target   (L3) : source catalog
# 219392596                        I2D exposure/target (L2b/L3): rectified 2D image

# %%
i2d = calibrated[(calibrated["productSubGroupDescription"] == "I2D")]

manifest = Observations.download_products(i2d, mrp_only=True)
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:JWST/product/jw02739-o001_t001_nircam_clear-f200w_i2d.fits to ./mastDownload/JWST/jw02739-o001_t001_nircam_clear-f200w/jw02739-o001_t001_nircam_clear-f200w_i2d.fits ... [Done]

# %%
manifest
# Out:
# <Table length=1>
#                                               Local Path                                               ...
#                                                 str102                                                 ...
# ------------------------------------------------------------------------------------------------------ ...
# ./mastDownload/JWST/jw02739-o001_t001_nircam_clear-f200w/jw02739-o001_t001_nircam_clear-f200w_i2d.fits ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.colors import LogNorm
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %%
dp_219392596 = fits.open(manifest['Local Path'][0])

# %%
dp_219392596.info()
# Out:
# Filename: ./mastDownload/JWST/jw02739-o001_t001_nircam_clear-f200w/jw02739-o001_t001_nircam_clear-f200w_i2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     363   ()
#   1  SCI           1 ImageHDU        75   (14344, 8589)   float32
#   2  ERR           1 ImageHDU        10   (14344, 8589)   float32
#   3  CON           1 ImageHDU        10   (14344, 8589, 5)   int32
#   4  WHT           1 ImageHDU         9   (14344, 8589)   float32
#   5  VAR_POISSON    1 ImageHDU         9   (14344, 8589)   float32
#   6  VAR_RNOISE    1 ImageHDU         9   (14344, 8589)   float32
#   7  VAR_FLAT      1 ImageHDU         9   (14344, 8589)   float32
#   8  HDRTAB        1 BinTableHDU    842   160R x 416C   [23A, 5A, 3A, 45A, 7A, 13A, 6A, 5A, 6A, 7A, 10A, 4A, L, D, D, D, D, 32A, 50A, 30A, 21A, 2A, D, D, D, 10A, 12A, 23A, 23A, 26A, 11A, 5A, 3A, 3A, 2A, 1A, 2A, 1A, L, 14A, 20A, 2A, 26A, 20A, 27A, 10A, K, L, L, L, L, 4A, 4A, 5A, D, D, D, D, D, D, 27A, D, D, D, 6A, 5A, 1A, 5A, 5A, 5A, L, D, D, D, D, D, D, D, D, D, D, D, D, 4A, D, D, D, D, D, D, D, D, D, K, 5A, 9A, D, D, D, D, D, D, D, D, D, 7A, D, D, K, K, D, D, K, K, D, D, K, K, K, K, K, D, D, D, D, D, D, D, D, D, K, K, L, L, K, K, D, D, D, D, D, D, D, 4A, K, K, K, K, K, K, D, D, D, D, 7A, 6A, K, K, D, K, D, D, D, D, D, K, 8A, D, D, D, D, D, D, D, D, D, D, 7A, 10A, D, D, D, D, D, D, D, D, D, D, D, D, D, 10A, 11A, D, D, D, D, D, D, D, D, D, D, D, D, K, K, D, 4A, K, K, K, D, 4A, K, K, K, D, 4A, K, D, D, K, 27A, 27A, 10A, D, D, D, D, D, D, D, 9A, 27A, D, D, D, D, D, D, D, 8A, 14A, 33A, D, D, 3A, 3A, D, 33A, 3A, 39A, D, D, D, 41A, 33A, 3A, 3A, 3A, 3A, 3A, D, D, 33A, 3A, 3A, 3A, D, D, 38A, 33A, 3A, D, D, D, 3A, D, D, 35A, D, 38A, D, 3A, D, D, D, D, 39A, D, D, D, 3A, D, 38A, D, D, D, D, D, D, 3A, D, D, D, D, D, 8A, D, D, D, D, 7A, D, D, 8A, 8A, D, D, D, D, D, D, 8A, D, 7A, 7A, D, D, 7A, 8A, D, D, 8A, D, D, D, 8A, D, 7A, 8A, D, 8A, 8A, D, D, D, D, 8A, 8A, D, D, D, D, D, 8A, D, 8A, D, D, D, 5A, D, L, 6A, D, D, D, D, 4A, D, D, D, K, D, D, D, D, D, D, 12A, 12A, D, 3A, 3A, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, 125A, D, D, D, D, D, D, K, D, D, D, D]
#   9  ASDF          1 BinTableHDU     11   1R x 1C   [37781B]

# %%
print("Header of HDU 1 - the 'SCI' ")
dp_219392596[1].header
# Out:
# Header of HDU 1 - the 'SCI'
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                14344
# NAXIS2  =                 8589
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# MJD-BEG =    59805.40325079491 / [d] exposure start time in MJD
# MJD-AVG =    59810.34146976117 / [d] exposure mid-point in MJD
# MJD-END =    59824.93756190972 / [d] exposure end time in MJD
# TDB-BEG =     59805.4080581956 / [d] TDB time of exposure start in MJD
# TDB-MID =   59810.345876725136 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59824.940783028695 / [d] TDB time of exposure end in MJD
# XPOSURE =   3221.0400000000004 / [s] Effective exposure time
# TELAPSE =   3221.0400000000004 / [s] Total elapsed exposure time
#
#         JWST ephemeris information
#
# REFFRAME= 'EME2000 '           / Ephemeris reference frame
# EPH_TYPE= 'Definitive'         / Definitive or Predicted
# EPH_TIME=    59805.40424568102 / [d] MJD time of position and velocity vectors
# JWST_X  =   117605813.75930214 / [km] barycentric JWST X coordinate at MJD_AVG
# JWST_Y  =    -88025037.0067838 / [km] barycentric JWST Y coordinate at MJD_AVG
# JWST_Z  =  -38382934.602064006 / [km] barycentric JWST Z coordinate at MJD_AVG
# OBSGEO-X=    704565535.1750071 / [m] geocentric JWST X coordinate at MJD_AVG
# OBSGEO-Y=  -1254992484.2486389 / [m] geocentric JWST Y coordinate at MJD_AVG
# OBSGEO-Z=   -801006314.5849954 / [m] geocentric JWST Z coordinate at MJD_AVG
# JWST_DX =    18.28969444988139 / [km/s] barycentric JWST X velocity at MJD_AVG
# JWST_DY =    21.27387727262541 / [km/s] barycentric JWST Y velocity at MJD_AVG
# JWST_DZ =    9.377814287052953 / [km/s] barycentric JWST Z velocity at MJD_AVG
# OBSGEODX=   150.57936764463278 / [m/s] geocentric JWST X velocity at MJD_AVG
# OBSGEODY=    74.49738730628818 / [m/s] geocentric JWST Y velocity at MJD_AVG
# OBSGEODZ=   188.62989237837252 / [m/s] geocentric JWST Z velocity at MJD_AVG
# PA_APER =     91.8320365420214 / [deg] Position angle of aperture used
# VA_SCALE=   0.9999287381185694 / Velocity aberration scale factor
# BUNIT   = 'MJy/sr  '           / physical units of the array values
#
#         Photometry information
#
# PHOTMJSR=   1.9639999866485596 / Flux density (MJy/steradian) producing 1 cps
# PHOTUJA2=    46.16270126497025 / Flux density (uJy/arcsec2) producing 1 cps
# PIXAR_SR= 2.29183188986268E-14 / Nominal pixel area in steradians
# PIXAR_A2= 0.000975063780443602 / Nominal pixel area in arcsec^2
#
#         Information about the coordinates in the file
#
# RADESYS = 'ICRS    '           / Name of the coordinate reference frame
#
#         Spacecraft pointing information
#
# RA_V1   =    274.8870583888703 / [deg] RA of telescope V1 axis
# DEC_V1  =  -13.839823492831888 / [deg] Dec of telescope V1 axis
# PA_V3   =    92.34742958541517 / [deg] Position angle of telescope V3 axis
#
#         WCS parameters
#
# WCSAXES =                    2 / number of World Coordinate System axes
# CRPIX1  =    7185.302135244601 / axis 1 coordinate of the reference pixel
# CRPIX2  =    4294.481488277661 / axis 2 coordinate of the reference pixel
# CRVAL1  =    274.7298929213127 / first axis value at the reference pixel
# CRVAL2  =   -13.85172827244205 / second axis value at the reference pixel
# CTYPE1  = 'RA---TAN'           / Axis 1 type
# CTYPE2  = 'DEC--TAN'           / Axis 2 type
# CUNIT1  = 'deg     '           / Axis 1 units
# CUNIT2  = 'deg     '           / Axis 2 units
# CDELT1  = 8.67389202215512E-06 / Axis 1 coordinate increment at reference point
# CDELT2  = 8.67389202215512E-06 / Axis 2 coordinate increment at reference point
# PC1_1   = 0.031969621374702016 / linear transformation matrix element
# PC1_2   =    0.999488841012824 / linear transformation matrix element
# PC2_1   =    0.999488841012824 / linear transformation matrix element
# PC2_2   = -0.03196962137470201 / linear transformation matrix element
# S_REGION= 'POLYGON ICRS  274.689493363 -13.912818346 274.766206195 &'
# CONTINUE  '-13.915200720 274.770282437 -13.790845449 274.693610607 &'
# CONTINUE  '-13.788464350&'
# CONTINUE  '' / spatial extent of the observation
# VELOSYS =             21365.79 / [m/s] Barycentric correction to radial velocity
# EXTVER  =                    1 / extension value

# %%
data = dp_219392596[1].data
print("Data Shape: ", np.shape(data))
# Out:
# Data Shape:  (8589, 14344)

# %%
plt.figure()
plt.imshow(data, cmap='gray')
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(data, cmap='gray', interpolation='nearest', vmin=0, vmax=20)
plt.colorbar()
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 10))
plt.imshow(data, cmap='gray', interpolation='nearest', vmin=0, vmax=15)
plt.axis('off')


plt.draw()

plt.savefig('pillars_of_creation.png', dpi=300, bbox_inches='tight', pad_inches=0)  # Saves as PNG with high resolution

plt.show()
